# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import scipy.stats as st

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import statistics

# %%
file_path = "Resources/alzheimers_prediction_dataset.csv"
df = pd.read_csv(file_path)

# %%
#Plot Histogram Chart by Age
sns.histplot(df["Age"])
plt.title("Age Distribution Of Participants")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
df["Age Group"] = pd.cut(df["Age"], bins=[50, 60, 70, 80, 90, 100], labels=["50-60", "60-70", "70-80", "80-90", "90+"])
sns.countplot(data=df, x="Age Group", hue="Alzheimer’s Diagnosis")
plt.title("Alzheimer’s Diagnosis by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Diagnosis Count")
plt.show()
